# %% [markdown]
# **TASK-5B: Please give concrete examples for each of the 4 domains of machine learning including classification, regression, clustering, and dimensionality reduction.**

# %% [markdown]
# In this graph, feature 1 represents the sales amount and feature 2 represents the years.
#
# **Blues**: Mp3
#
# **Browns**: Walkman

# %% [markdown]
# ![05.01-classification-1.png](data:image/png;base64,...)

# %% [markdown]
# In this graph, feature 1 represents beak length and feature 2 represents body weight. Colors represent bird species.

# %% [markdown]
# ![05.01-regression-1.png](data:image/png;base64,...)

# %% [markdown]
# In this graph, feature 1 represents weight and feature 2 represents height.
#
# **Blues:**  Small
#
# **Yellows:** Medium
#
# **Purples:** Large
#
# **Greens:** XLarge

# %% [markdown]
# ![05.01-clustering-2.png](data:image/png;base64,...)

# %% [markdown]
# Feature 1 represents the deposit interest rate and feature 2 represents the loan interest rate. Colors represent banks.
#
# **NOTE:** Rates are treated as different times within 1 year.

# %% [markdown]
# ![05.01-dimesionality-2.png](data:image/png;base64,...)

# %% [markdown]
# **TASK-5C: Please run the GaussianNB algorithm for 20 different values with respect to varr_smoothing parameter to find the best model. Then please visualize your findings via a lineplot (matplotlib) to illustrate the more appropriate values/ranges**

# %%
from sklearn.naive_bayes import GaussianNB                           
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
from numpy import random

iris = sns.load_dataset('iris')
X_iris= iris.drop('species', axis=1)
y_iris = iris['species']

Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, random_state=0)

values=random.rand(20)
list1=[]
for i in values:
  model = GaussianNB(var_smoothing=i)
  model.fit(Xtrain, ytrain)
  y_model = model.predict(Xtest)
  Acc=accuracy_score(ytest, y_model)
  list1.append(Acc)
print(list1)
# Out:
# [0.8947368421052632, 0.8947368421052632, 0.9210526315789473, 0.868421052631579, 0.9210526315789473, 0.9210526315789473, 1.0, 0.868421052631579, 0.9210526315789473, 0.8947368421052632, 0.9210526315789473, 0.9210526315789473, 0.9210526315789473, 0.8947368421052632, 0.8947368421052632, 0.9210526315789473, 0.9210526315789473, 0.8947368421052632, 0.8947368421052632, 0.9473684210526315]

# %%
list1
# Out:
# [0.8947368421052632,
#  0.8947368421052632,
#  0.9210526315789473,
#  0.868421052631579,
#  0.9210526315789473,
#  0.9210526315789473,
#  1.0,
#  0.868421052631579,
#  0.9210526315789473,
#  0.8947368421052632,
#  0.9210526315789473,
#  0.9210526315789473,
#  0.9210526315789473,
#  0.8947368421052632,
#  0.8947368421052632,
#  0.9210526315789473,
#  0.9210526315789473,
#  0.8947368421052632,
#  0.8947368421052632,
#  0.9473684210526315]

# %%
print("The best accuracy score: ", max(list1))
# Out:
# The best accuracy score:  1.0

# %%
import matplotlib.pyplot as plt
plt.plot(list1);
plt.title("Accuracy values ​​for 20 random values")
# Out:
# Text(0.5, 1.0, 'Accuracy values \u200b\u200bfor 20 random values')

# %% [markdown]
# **TASK-5D: Please use two different algorithms (other than GaussianNB) with their default parameter values and then compare your findings to the ones obtained in Task-5C.**

# %% [markdown]
# ### SGD Classifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
import numpy as np
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report
from sklearn.preprocessing import scale
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris,
                                                random_state=0)

# %%
model = SGDClassifier(max_iter=1000,tol=0.02)
model.fit(Xtrain, ytrain)   
y_model = model.predict(Xtest)

# %%
Accuracy_1=(accuracy_score(ytest, y_model))
print(Accuracy_1)
# Out:
# 0.8157894736842105

# %% [markdown]
# ### KNN Classifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns


iris = sns.load_dataset('iris')
X = iris.drop('species', axis=1)
y = iris['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05,
                                                random_state=0)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=7)
knn_model.fit(X_train, y_train)
y1_model = model.predict(X_test)

# %%
Accuracy_2=(accuracy_score(y_test, y1_model))
print(Accuracy_2)
# Out:
# 0.875
